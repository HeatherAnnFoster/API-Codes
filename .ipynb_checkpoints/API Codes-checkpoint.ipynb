# %% [markdown]
# # Imports and Tools for Data Analysis

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in c:\users\16024\anaconda3\envs\dojo-env\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\16024\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\16024\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\16024\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\16024\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\16024\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: tqdm in c:\users\16024\anaconda3\envs\dojo-env\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\16024\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.5)

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
# os - for saving and loading files
# json - to work with json files
# math - to round up results
# time - to add a short pause to not overwhelm the server
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %%
#Load API Credentials
with open('/Users/16024/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['Client-ID', 'API Key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['API Key'], timeout_s = 5.0)

# %% [markdown]
# # Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location = 'Myrtle Beach, SC 29572'
term = 'crab cakes'

# %%
location.split(',')[0]
# Out:
# 'Myrtle Beach'

# %%
## Specify fodler for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Myrtle Beach-crab cakes.json'

# %% [markdown]
# # Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Myrtle Beach-crab cakes.json already exists.

# %% [markdown]
# # Load JSON FIle and account for previous results

# %% [markdown]
# # Make the first API call to get the first page of data
#
# We will use this first result to check:
# how many total results there are?
# Where is the actual data we want to save?
# how many results do we get at a time?

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 122

# %%
results['region']
# Out:
# {'center': {'longitude': -78.78742218017578, 'latitude': 33.767435858441786}}

# %%
results['businesses']
# Out:
# [{'id': 'ua_NkrRhQ2PRMqHiCMtvng',
#   'alias': 'hook-and-barrel-myrtle-beach',
#   'name': 'Hook & Barrel',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/X3Tf3ZHvXX6KHy7lfwSG_Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hook-and-barrel-myrtle-beach?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 1217,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.75100667393175,
#    'longitude': -78.81334495248089},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '8014 N Kings Hwy',
#    'address2': None,
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['8014 N Kings Hwy', 'Myrtle Beach, SC 29572']},
#   'phone': '+18438395888',
#   'display_phone': '(843) 839-5888',
#   'distance': 3013.3442400349772},
#  {'id': 'm_5-5DloClXZPehwNh2H3Q',
#   'alias': 'good-fellas-seafood-hut-and-bar-north-myrtle-beach',
#   'name': 'Good Fellas Seafood Hut & Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/58GS3jcRXcs-4ZJaDC-3Vg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/good-fellas-seafood-hut-and-bar-north-myrtle-beach?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 458,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.799883925710574,
#    'longitude': -78.7341883447918},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4505 Hwy 17 S',
#    'address2': '',
#    'address3': '',
#    'city': 'North Myrtle Beach',
#    'zip_code': '29582',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['4505 Hwy 17 S', 'North Myrtle Beach, SC 29582']},
#   'phone': '+18432723079',
#   'display_phone': '(843) 272-3079',
#   'distance': 6101.030061802802},
#  {'id': 'n15j1cELynTq4oy3nBM4fQ',
#   'alias': 'biminis-oyster-bar-and-seafood-market-myrtle-beach-2',
#   'name': "Bimini's Oyster Bar & Seafood Market",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cm4oXhvWVeB5tSJCQ5NvFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/biminis-oyster-bar-and-seafood-market-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 1059,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.77758, 'longitude': -78.79105},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '930 Lake Arrowhead Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['930 Lake Arrowhead Rd', 'Myrtle Beach, SC 29572']},
#   'phone': '+18434495549',
#   'display_phone': '(843) 449-5549',
#   'distance': 1160.7315315002747},
#  {'id': 'Hx9_sM3JKxQHVd7GgKwIzg',
#   'alias': 'flying-fish-public-market-and-grill-north-myrtle-beach-2',
#   'name': 'Flying Fish Public Market & Grill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4aniFwfnm2c5AR9trmUaBg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flying-fish-public-market-and-grill-north-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 1840,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.801777, 'longitude': -78.742919},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '4744 Hwy 17 S',
#    'address2': '',
#    'address3': '',
#    'city': 'North Myrtle Beach',
#    'zip_code': '29582',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['4744 Hwy 17 S', 'North Myrtle Beach, SC 29582']},
#   'phone': '+18436633474',
#   'display_phone': '(843) 663-3474',
#   'distance': 5612.235970684538},
#  {'id': 'aeUtuP-khLI-8s2kgIV7Bw',
#   'alias': 'fire-and-smoke-gastropub-myrtle-beach-2',
#   'name': 'Fire and Smoke Gastropub',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-7IaWthC0hb8CWxe6keEkw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fire-and-smoke-gastropub-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 709,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.7477, 'longitude': -78.81557},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '411 79th Ave N',
#    'address2': None,
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['411 79th Ave N', 'Myrtle Beach, SC 29572']},
#   'phone': '+18434490085',
#   'display_phone': '(843) 449-0085',
#   'distance': 3406.23885932299},
#  {'id': 'DUAtVUXD9POcp8rEdsUsUA',
#   'alias': 'blueberrys-grill-myrtle-beach-2',
#   'name': "Blueberry's Grill",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4JlaGQCVAxglU-zmpCadZg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blueberrys-grill-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 1703,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.7513264664437,
#    'longitude': -78.81539014112055},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '7931 N Kings Hwy',
#    'address2': 'Ste 140',
#    'address3': None,
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['7931 N Kings Hwy',
#     'Ste 140',
#     'Myrtle Beach, SC 29572']},
#   'phone': '+18439454588',
#   'display_phone': '(843) 945-4588',
#   'distance': 3145.39102078337},
#  {'id': 'xslt-fHhDYNU9PeLMh3LiQ',
#   'alias': 'croakers-at-the-pier-myrtle-beach',
#   'name': 'Croakers at the Pier',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DOhBnrY0oBsnmXHWd2ZUGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/croakers-at-the-pier-myrtle-beach?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 175,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.76411, 'longitude': -78.782288},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '9700 Kings Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['9700 Kings Rd', 'Myrtle Beach, SC 29572']},
#   'phone': '+18434975331',
#   'display_phone': '(843) 497-5331',
#   'distance': 601.6683194503214},
#  {'id': 'gC30VQo5ekafPD3Gy4NzQw',
#   'alias': 'calli-bakers-firehouse-myrtle-beach-2',
#   'name': 'Calli Bakers Firehouse',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YCTzV2F1nJ_YjwQcEloOuA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/calli-bakers-firehouse-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 119,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.77715, 'longitude': -78.79086},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '910 Lake Arrowhead Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['910 Lake Arrowhead Rd', 'Myrtle Beach, SC 29572']},
#   'phone': '+18436920788',
#   'display_phone': '(843) 692-0788',
#   'distance': 1120.5621278676456},
#  {'id': 'E0WhPq7kJoczSalCIaaX3w',
#   'alias': 'thoroughbreds-chophouse-myrtle-beach',
#   'name': 'Thoroughbreds Chophouse',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WmMphVUShW3LUp6_XMCgGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thoroughbreds-chophouse-myrtle-beach?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 280,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.77912, 'longitude': -78.79079},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '9706 N Kings Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['9706 N Kings Hwy', 'Myrtle Beach, SC 29572']},
#   'phone': '+18434972636',
#   'display_phone': '(843) 497-2636',
#   'distance': 1351.8514426976399},
#  {'id': 'vpjnxiep2DLT7Hbzk6LtfA',
#   'alias': 'mr-fish-restaurant-myrtle-beach-2',
#   'name': 'Mr. Fish Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ozDe5BuSUUebNJYa49mGDw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mr-fish-restaurant-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 1655,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'southern', 'title': 'Southern'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.738095, 'longitude': -78.82995},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '6401 N Kings Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['6401 N Kings Hwy', 'Myrtle Beach, SC 29572']},
#   'phone': '+18438393474',
#   'display_phone': '(843) 839-3474',
#   'distance': 5106.9646025228885},
#  {'id': 'uLFlmPtgvKTNZNx3itZhvA',
#   'alias': 'carolina-roadhouse-myrtle-beach-3',
#   'name': 'Carolina Roadhouse',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3M75fDz59TwQtoEAlkKFYA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carolina-roadhouse-myrtle-beach-3?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 1266,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.72176, 'longitude': -78.8501299},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '4617 N Kings Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29577',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['4617 N Kings Hwy', 'Myrtle Beach, SC 29577']},
#   'phone': '+18434979911',
#   'display_phone': '(843) 497-9911',
#   'distance': 7702.40387943013},
#  {'id': 'mZ1uwV_PcKMRJFuAte4RNQ',
#   'alias': 'joes-bar-and-grill-north-myrtle-beach',
#   'name': "Joe's Bar & Grill",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eK8PIBq9bziO4MdsOSNIZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-bar-and-grill-north-myrtle-beach?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 496,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.797655, 'longitude': -78.739183},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '810 Conway St',
#    'address2': '',
#    'address3': '',
#    'city': 'North Myrtle Beach',
#    'zip_code': '29582',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['810 Conway St', 'North Myrtle Beach, SC 29582']},
#   'phone': '+18432724666',
#   'display_phone': '(843) 272-4666',
#   'distance': 5582.754214489342},
#  {'id': 'CId2jvUsGzrTfO3Zt2HTJw',
#   'alias': 'flamingo-grill-myrtle-beach-2',
#   'name': 'Flamingo Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/THZPGU54ROjNkAWiebzFJA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flamingo-grill-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 500,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.74262698504067,
#    'longitude': -78.82334455684256},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '7050 N Kings Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['7050 N Kings Hwy', 'Myrtle Beach, SC 29572']},
#   'phone': '+18434495388',
#   'display_phone': '(843) 449-5388',
#   'distance': 4317.301542261671},
#  {'id': 'DVRg-C4ZPO5xXcHka3t-wA',
#   'alias': 'aspen-grille-myrtle-beach',
#   'name': 'Aspen Grille',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8sAt99zvKbqug4rzbpCTYQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aspen-grille-myrtle-beach?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 384,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.7254905700684,
#    'longitude': -78.8450546264648},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '5101 N Kings Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29577',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['5101 N Kings Hwy', 'Myrtle Beach, SC 29577']},
#   'phone': '+18434499191',
#   'display_phone': '(843) 449-9191',
#   'distance': 7096.859530088104},
#  {'id': 'TVuE58oxg6vMO7WaZRg1_Q',
#   'alias': 'bar-19-twelve-north-myrtle-beach',
#   'name': 'Bar 19 Twelve',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0TlXo8y1vbtedR7ssjLK5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bar-19-twelve-north-myrtle-beach?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 71,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.810737, 'longitude': -78.708104},
#   'transactions': ['delivery'],
#   'location': {'address1': '1912 Hwy 17 S',
#    'address2': '',
#    'address3': None,
#    'city': 'North Myrtle Beach',
#    'zip_code': '29582',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['1912 Hwy 17 S', 'North Myrtle Beach, SC 29582']},
#   'phone': '+18432810997',
#   'display_phone': '(843) 281-0997',
#   'distance': 8769.958137033454},
#  {'id': 'rcIGBvlfyo248S44anbz-Q',
#   'alias': 'lulus-north-myrtle-beach-north-myrtle-beach-3',
#   'name': "LuLu's North Myrtle Beach",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/J5NSGI1u2VJQU7d0OyA3lA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lulus-north-myrtle-beach-north-myrtle-beach-3?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 724,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.80064, 'longitude': -78.746588},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4954 Hwy 17 S',
#    'address2': '',
#    'address3': None,
#    'city': 'North Myrtle Beach',
#    'zip_code': '29582',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['4954 Hwy 17 S', 'North Myrtle Beach, SC 29582']},
#   'phone': '+18434915011',
#   'display_phone': '(843) 491-5011',
#   'distance': 5295.616590307476},
#  {'id': '8movtWGs8Z35KaioiWo_bQ',
#   'alias': 'captain-georges-seafood-restaurant-myrtle-beach-5',
#   'name': "Captain George's Seafood Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/luDMDIT0k8OQDUoViwxL3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/captain-georges-seafood-restaurant-myrtle-beach-5?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 1941,
#   'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.72096, 'longitude': -78.88244},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '1401 29th Ave N',
#    'address2': '',
#    'address3': None,
#    'city': 'Myrtle Beach',
#    'zip_code': '29577',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['1401 29th Ave N', 'Myrtle Beach, SC 29577']},
#   'phone': '+18439162278',
#   'display_phone': '(843) 916-2278',
#   'distance': 10197.252949234851},
#  {'id': 'axmKdmOZuJk9OLLlRQM8wQ',
#   'alias': 'the-original-benjamins-calabash-seafood-myrtle-beach-2',
#   'name': "The Original Benjamin's Calabash Seafood",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xvOhVrBdDu0NVLJNL0LtQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-original-benjamins-calabash-seafood-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 820,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'buffets', 'title': 'Buffets'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.77743382787479,
#    'longitude': -78.79570866788579},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '9593 N Kings Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['9593 N Kings Hwy', 'Myrtle Beach, SC 29572']},
#   'phone': '+18434490821',
#   'display_phone': '(843) 449-0821',
#   'distance': 1350.0264264667255},
#  {'id': '90T3Tls0ZHVeC_u2g9Y4SQ',
#   'alias': 'pier-14-restaurant-and-lounge-myrtle-beach-2',
#   'name': 'Pier 14 Restaurant & Lounge',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IOuxOZ08JPWNazrBPuN5-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pier-14-restaurant-and-lounge-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 815,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.69473167, 'longitude': -78.87528667},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1306 N Ocean Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29577',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['1306 N Ocean Blvd', 'Myrtle Beach, SC 29577']},
#   'phone': '+18434484314',
#   'display_phone': '(843) 448-4314',
#   'distance': 11457.596914907097},
#  {'id': 'aikuRhOVO6XtYq7hu6t1MA',
#   'alias': 'giant-crab-seafood-restaurant-myrtle-beach-2',
#   'name': 'Giant Crab Seafood Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GqK7FLkA5B-pU8zvBVymoQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/giant-crab-seafood-restaurant-myrtle-beach-2?adjust_creative=I3f1IKLgCLR1LZhf2A3n_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=I3f1IKLgCLR1LZhf2A3n_A',
#   'review_count': 487,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'buffets', 'title': 'Buffets'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 33.77804, 'longitude': -78.79439},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '9597 N Kings Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Myrtle Beach',
#    'zip_code': '29572',
#    'country': 'US',
#    'state': 'SC',
#    'display_address': ['9597 N Kings Hwy', 'Myrtle Beach, SC 29572']},
#   'phone': '+18434491097',
#   'display_phone': '(843) 449-1097',
#   'distance': 1376.6609307353613}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                              alias  \
# 0   ua_NkrRhQ2PRMqHiCMtvng                       hook-and-barrel-myrtle-beach
# 1   m_5-5DloClXZPehwNh2H3Q  good-fellas-seafood-hut-and-bar-north-myrtle-b...
# 2   n15j1cELynTq4oy3nBM4fQ  biminis-oyster-bar-and-seafood-market-myrtle-b...
# 3   Hx9_sM3JKxQHVd7GgKwIzg  flying-fish-public-market-and-grill-north-myrt...
# 4   aeUtuP-khLI-8s2kgIV7Bw            fire-and-smoke-gastropub-myrtle-beach-2
# 5   DUAtVUXD9POcp8rEdsUsUA                    blueberrys-grill-myrtle-beach-2
# 6   xslt-fHhDYNU9PeLMh3LiQ                  croakers-at-the-pier-myrtle-beach
# 7   gC30VQo5ekafPD3Gy4NzQw              calli-bakers-firehouse-myrtle-beach-2
# 8   E0WhPq7kJoczSalCIaaX3w               thoroughbreds-chophouse-myrtle-beach
# 9   vpjnxiep2DLT7Hbzk6LtfA                  mr-fish-restaurant-myrtle-beach-2
# 10  uLFlmPtgvKTNZNx3itZhvA                  carolina-roadhouse-myrtle-beach-3
# 11  mZ1uwV_PcKMRJFuAte4RNQ              joes-bar-and-grill-north-myrtle-beach
# 12  CId2jvUsGzrTfO3Zt2HTJw                      flamingo-grill-myrtle-beach-2
# 13  DVRg-C4ZPO5xXcHka3t-wA                          aspen-grille-myrtle-beach
# 14  TVuE58oxg6vMO7WaZRg1_Q                   bar-19-twelve-north-myrtle-beach
# 15  rcIGBvlfyo248S44anbz-Q      lulus-north-myrtle-beach-north-myrtle-beach-3
# 16  8movtWGs8Z35KaioiWo_bQ  captain-georges-seafood-restaurant-myrtle-beach-5
# 17  axmKdmOZuJk9OLLlRQM8wQ  the-original-benjamins-calabash-seafood-myrtle...
# 18  90T3Tls0ZHVeC_u2g9Y4SQ       pier-14-restaurant-and-lounge-myrtle-beach-2
# 19  aikuRhOVO6XtYq7hu6t1MA       giant-crab-seafood-restaurant-myrtle-beach-2
#
#                                         name  \
# 0                              Hook & Barrel
# 1              Good Fellas Seafood Hut & Bar
# 2       Bimini's Oyster Bar & Seafood Market
# 3          Flying Fish Public Market & Grill
# 4                   Fire and Smoke Gastropub
# 5                          Blueberry's Grill
# 6                       Croakers at the Pier
# 7                     Calli Bakers Firehouse
# 8                    Thoroughbreds Chophouse
# 9                        Mr. Fish Restaurant
# 10                        Carolina Roadhouse
# 11                         Joe's Bar & Grill
# 12                            Flamingo Grill
# 13                              Aspen Grille
# 14                             Bar 19 Twelve
# 15                 LuLu's North Myrtle Beach
# 16       Captain George's Seafood Restaurant
# 17  The Original Benjamin's Calabash Seafood
# 18               Pier 14 Restaurant & Lounge
# 19             Giant Crab Seafood Restaurant
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/X3Tf3Z...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/58GS3j...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/cm4oXh...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/4aniFw...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/-7IaWt...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/4JlaGQ...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/DOhBnr...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/YCTzV2...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/WmMphV...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/ozDe5B...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/3M75fD...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/eK8PIB...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/THZPGU...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/8sAt99...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/0TlXo8...      False
# 15  https://s3-media4.fl.yelpcdn.com/bphoto/J5NSGI...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/luDMDI...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/xvOhVr...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/IOuxOZ...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/GqK7FL...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/hook-and-barrel-myrtl...          1217
# 1   https://www.yelp.com/biz/good-fellas-seafood-h...           458
# 2   https://www.yelp.com/biz/biminis-oyster-bar-an...          1059
# 3   https://www.yelp.com/biz/flying-fish-public-ma...          1840
# 4   https://www.yelp.com/biz/fire-and-smoke-gastro...           709
# 5   https://www.yelp.com/biz/blueberrys-grill-myrt...          1703
# 6   https://www.yelp.com/biz/croakers-at-the-pier-...           175
# 7   https://www.yelp.com/biz/calli-bakers-firehous...           119
# 8   https://www.yelp.com/biz/thoroughbreds-chophou...           280
# 9   https://www.yelp.com/biz/mr-fish-restaurant-my...          1655
# 10  https://www.yelp.com/biz/carolina-roadhouse-my...          1266
# 11  https://www.yelp.com/biz/joes-bar-and-grill-no...           496
# 12  https://www.yelp.com/biz/flamingo-grill-myrtle...           500
# 13  https://www.yelp.com/biz/aspen-grille-myrtle-b...           384
# 14  https://www.yelp.com/biz/bar-19-twelve-north-m...            71
# 15  https://www.yelp.com/biz/lulus-north-myrtle-be...           724
# 16  https://www.yelp.com/biz/captain-georges-seafo...          1941
# 17  https://www.yelp.com/biz/the-original-benjamin...           820
# 18  https://www.yelp.com/biz/pier-14-restaurant-an...           815
# 19  https://www.yelp.com/biz/giant-crab-seafood-re...           487
#
#                                            categories  rating  \
# 0   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 1          [{'alias': 'seafood', 'title': 'Seafood'}]     4.5
# 2   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 3   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 4        [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5
# 5   [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 6   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 7   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 8   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 9   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 10  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.0
# 11  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 12  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 13  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 14  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 15  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.5
# 16  [{'alias': 'buffets', 'title': 'Buffets'}, {'a...     4.0
# 17  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.5
# 18  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 19  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 33.75100667393175, 'longitude': -...          [delivery]
# 1   {'latitude': 33.799883925710574, 'longitude': ...          [delivery]
# 2      {'latitude': 33.77758, 'longitude': -78.79105}          [delivery]
# 3    {'latitude': 33.801777, 'longitude': -78.742919}  [pickup, delivery]
# 4       {'latitude': 33.7477, 'longitude': -78.81557}          [delivery]
# 5   {'latitude': 33.7513264664437, 'longitude': -7...  [pickup, delivery]
# 6     {'latitude': 33.76411, 'longitude': -78.782288}          [delivery]
# 7      {'latitude': 33.77715, 'longitude': -78.79086}  [pickup, delivery]
# 8      {'latitude': 33.77912, 'longitude': -78.79079}          [delivery]
# 9     {'latitude': 33.738095, 'longitude': -78.82995}          [delivery]
# 10   {'latitude': 33.72176, 'longitude': -78.8501299}  [pickup, delivery]
# 11   {'latitude': 33.797655, 'longitude': -78.739183}          [delivery]
# 12  {'latitude': 33.74262698504067, 'longitude': -...          [delivery]
# 13  {'latitude': 33.7254905700684, 'longitude': -7...          [delivery]
# 14   {'latitude': 33.810737, 'longitude': -78.708104}          [delivery]
# 15    {'latitude': 33.80064, 'longitude': -78.746588}          [delivery]
# 16     {'latitude': 33.72096, 'longitude': -78.88244}  [pickup, delivery]
# 17  {'latitude': 33.77743382787479, 'longitude': -...                  []
# 18  {'latitude': 33.69473167, 'longitude': -78.875...          [delivery]
# 19     {'latitude': 33.77804, 'longitude': -78.79439}                  []
#
#    price                                           location         phone  \
# 0     $$  {'address1': '8014 N Kings Hwy', 'address2': N...  +18438395888
# 1     $$  {'address1': '4505 Hwy 17 S', 'address2': '', ...  +18432723079
# 2     $$  {'address1': '930 Lake Arrowhead Rd', 'address...  +18434495549
# 3     $$  {'address1': '4744 Hwy 17 S', 'address2': '', ...  +18436633474
# 4    $$$  {'address1': '411 79th Ave N', 'address2': Non...  +18434490085
# 5     $$  {'address1': '7931 N Kings Hwy', 'address2': '...  +18439454588
# 6     $$  {'address1': '9700 Kings Rd', 'address2': '', ...  +18434975331
# 7     $$  {'address1': '910 Lake Arrowhead Rd', 'address...  +18436920788
# 8    $$$  {'address1': '9706 N Kings Hwy', 'address2': '...  +18434972636
# 9     $$  {'address1': '6401 N Kings Hwy', 'address2': '...  +18438393474
# 10    $$  {'address1': '4617 N Kings Hwy', 'address2': '...  +18434979911
# 11    $$  {'address1': '810 Conway St', 'address2': '', ...  +18432724666
# 12   $$$  {'address1': '7050 N Kings Hwy', 'address2': '...  +18434495388
# 13   $$$  {'address1': '5101 N Kings Hwy', 'address2': '...  +18434499191
# 14   NaN  {'address1': '1912 Hwy 17 S', 'address2': '', ...  +18432810997
# 15    $$  {'address1': '4954 Hwy 17 S', 'address2': '', ...  +18434915011
# 16   $$$  {'address1': '1401 29th Ave N', 'address2': ''...  +18439162278
# 17   $$$  {'address1': '9593 N Kings Hwy', 'address2': '...  +18434490821
# 18    $$  {'address1': '1306 N Ocean Blvd', 'address2': ...  +18434484314
# 19   $$$  {'address1': '9597 N Kings Hwy', 'address2': '...  +18434491097
#
#      display_phone      distance
# 0   (843) 839-5888   3013.344240
# 1   (843) 272-3079   6101.030062
# 2   (843) 449-5549   1160.731532
# 3   (843) 663-3474   5612.235971
# 4   (843) 449-0085   3406.238859
# 5   (843) 945-4588   3145.391021
# 6   (843) 497-5331    601.668319
# 7   (843) 692-0788   1120.562128
# 8   (843) 497-2636   1351.851443
# 9   (843) 839-3474   5106.964603
# 10  (843) 497-9911   7702.403879
# 11  (843) 272-4666   5582.754214
# 12  (843) 449-5388   4317.301542
# 13  (843) 449-9191   7096.859530
# 14  (843) 281-0997   8769.958137
# 15  (843) 491-5011   5295.616590
# 16  (843) 916-2278  10197.252949
# 17  (843) 449-0821   1350.026426
# 18  (843) 448-4314  11457.596915
# 19  (843) 449-1097   1376.660931

# %% [markdown]
# # Where is the actual data we want to save?

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# # Calculate how many pages of results needed to cover the total_results

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 7

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# # Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                              alias  \
# 0  m_5-5DloClXZPehwNh2H3Q  good-fellas-seafood-hut-and-bar-north-myrtle-b...
# 1  n15j1cELynTq4oy3nBM4fQ  biminis-oyster-bar-and-seafood-market-myrtle-b...
# 2  Hx9_sM3JKxQHVd7GgKwIzg  flying-fish-public-market-and-grill-north-myrt...
# 3  aeUtuP-khLI-8s2kgIV7Bw            fire-and-smoke-gastropub-myrtle-beach-2
# 4  DUAtVUXD9POcp8rEdsUsUA                    blueberrys-grill-myrtle-beach-2
#
#                                    name  \
# 0         Good Fellas Seafood Hut & Bar
# 1  Bimini's Oyster Bar & Seafood Market
# 2     Flying Fish Public Market & Grill
# 3              Fire and Smoke Gastropub
# 4                     Blueberry's Grill
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/58GS3j...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/cm4oXh...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/4aniFw...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/-7IaWt...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/4JlaGQ...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/good-fellas-seafood-h...           458
# 1  https://www.yelp.com/biz/biminis-oyster-bar-an...          1059
# 2  https://www.yelp.com/biz/flying-fish-public-ma...          1840
# 3  https://www.yelp.com/biz/fire-and-smoke-gastro...           709
# 4  https://www.yelp.com/biz/blueberrys-grill-myrt...          1703
#
#                                           categories  rating  \
# 0         [{'alias': 'seafood', 'title': 'Seafood'}]     4.5
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 2  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 3       [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5
# 4  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 33.799883925710574, 'longitude': ...          [delivery]
# 1     {'latitude': 33.77758, 'longitude': -78.79105}          [delivery]
# 2   {'latitude': 33.801777, 'longitude': -78.742919}  [delivery, pickup]
# 3      {'latitude': 33.7477, 'longitude': -78.81557}          [delivery]
# 4  {'latitude': 33.7513264664437, 'longitude': -7...  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '4505 Hwy 17 S', 'address2': '', ...  +18432723079
# 1    $$  {'address1': '930 Lake Arrowhead Rd', 'address...  +18434495549
# 2    $$  {'address1': '4744 Hwy 17 S', 'address2': '', ...  +18436633474
# 3   $$$  {'address1': '411 79th Ave N', 'address2': Non...  +18434490085
# 4    $$  {'address1': '7931 N Kings Hwy', 'address2': '...  +18439454588
#
#     display_phone     distance
# 0  (843) 272-3079  6101.030062
# 1  (843) 449-5549  1160.731532
# 2  (843) 663-3474  5612.235971
# 3  (843) 449-0085  3406.238859
# 4  (843) 945-4588  3145.391021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             120 non-null    object
#  1   alias          120 non-null    object
#  2   name           120 non-null    object
#  3   image_url      120 non-null    object
#  4   is_closed      120 non-null    bool
#  5   url            120 non-null    object
#  6   review_count   120 non-null    int64
#  7   categories     120 non-null    object
#  8   rating         120 non-null    float64
#  9   coordinates    120 non-null    object
#  10  transactions   120 non-null    object
#  11  price          111 non-null    object
#  12  location       120 non-null    object
#  13  phone          120 non-null    object
#  14  display_phone  120 non-null    object
#  15  distance       120 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 14.3+ KB

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Myrtle Beach-crab cakes.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)
